# %% [markdown]
# # Detection

# %% [markdown]
# ## MMDetection

# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv

# %% [markdown]
# ## Choose the config file and download the model
#
# You might need to download the models you need manually

# %%
config_file = './mmdetection_configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py'
# download the checkpoint from model zoo and put it in `checkpoints/`
# url: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
checkpoint_file = './checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'

# %% [markdown]
# ## Initialize the model with the checkpoint

# %%
model = init_detector(config_file, checkpoint_file, device='cuda:0')
# Out:
# load checkpoint from local path: ./checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth

# %% [markdown]
# ## Inference with the image provided.

# %%
img = 'pictures/det.jpg'
result = inference_detector(model, img)
# Out:
# /home/huaijin/anaconda3/lib/python3.8/site-packages/mmdet/datasets/utils.py:65: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   warnings.warn(

# %% [markdown]
# ## Show the results.

# %%
show_result_pyplot(model, img, result)

# %% [markdown]
# ## Your turn
#
# You should use your image and do the inference.
#
# You should also provide another segmentation model results with this image.

# %% [markdown]
# # Semantic segmentation

# %% [markdown]
# ## MMSegmentation

# %%
from mmseg.apis import init_segmentor, inference_segmentor, show_result_pyplot
from mmseg.core.evaluation import get_palette
import mmcv

# %% [markdown]
# ## Download the checkpoint

# %%
# Download the checkpoint
# !wget https://openmmlab.oss-accelerate.aliyuncs.com/mmsegmentation/v0.5/deeplabv3/deeplabv3_r50-d8_512x1024_40k_cityscapes/deeplabv3_r50-d8_512x1024_40k_cityscapes_20200605_022449-acadc2f8.pth -P ../checkpoints

# %% [markdown]
# ## Choose the config file and the checkpoint

# %%
config_file = './mmsegmentation_configs/deeplabv3/deeplabv3_r50-d8_512x1024_40k_cityscapes.py'
checkpoint_file = './checkpoints/deeplabv3_r50-d8_512x1024_40k_cityscapes_20200605_022449-acadc2f8.pth'

# %% [markdown]
# ## Initialize the model with the checkpoint

# %%
# build the model from a config file and a checkpoint file
model = init_segmentor(config_file, checkpoint_file, device='cuda:0')
# Out:
# load checkpoint from local path: ./checkpoints/deeplabv3_r50-d8_512x1024_40k_cityscapes_20200605_022449-acadc2f8.pth

# %% [markdown]
# ## Inference with the image provided.

# %%
# test a single image
img = './pictures/seg.png'
result = inference_segmentor(model, img)

# %% [markdown]
# ## Show the results

# %%
# show the results
show_result_pyplot(model, img, result, get_palette('cityscapes'))
# Out:
# /mnt/data/huaijin/cv_ta/project/mmsegmentation/mmseg/models/segmentors/base.py:268: UserWarning: show==False and out_file is not specified, only result image will be returned
#   warnings.warn('show==False and out_file is not specified, only '

# %% [markdown]
# ## Your turn
#
# You should use your image and do the inference.
#
# You should also provide another segmentation model results with this image.
